// %% [markdown]
// # Running XGBoost on Azure HDInsight
// This Notebook will walk you through on the detailed steps on how to build, install, and run XGBoost on HDInsight, the managed Hadoop and Spark solution on Azure. This notebook is authored by Xiaoyong Zhu, Program Manager in HDInsight team.
// ![XGBoost](https://raw.githubusercontent.com/dmlc/dmlc.github.io/master/img/logo-m/xgboost.png)

// %% [markdown]
// ### XGBoost
// XGBoost is an optimized distributed gradient boosting library designed to be highly efficient, flexible and portable. It implements machine learning algorithms under the Gradient Boosting framework. XGBoost provides a parallel tree boosting (also known as GBDT, GBM) that solve many data science problems in a fast and accurate way. The same code runs on major distributed environment (Hadoop, SGE, MPI) and can solve problems beyond billions of examples.
//
// It is not designed as a generic Machine Learning framework; it is designed as a library very specialized in boosting tree algorithm, and is widely used from production to experimental projects.
//
// For more details on XGBoost, please go to XGBoost [GitHub page](https://github.com/dmlc/xgboost).

// %% [markdown]
// ### XGBoost with Spark
// The following figure illustrates the new pipeline architecture with the latest XGBoost4J-Spark.
// ![XGBoost with Spark](https://raw.githubusercontent.com/dmlc/web-data/master/xgboost/unified_pipeline_new.png)
//
// With XGBoost4J-Spark, users are able to use both low- and high-level memory abstraction in Spark, i.e. RDD and DataFrame/Dataset. The DataFrame/Dataset abstraction grants the user to manipulate structured datasets and utilize the built-in routines in Spark or User Defined Functions (UDF) to explore the value distribution in columns before they feed data into the machine learning phase in the pipeline. In the following example, the structured sales records can be saved in a JSON file, parsed as DataFrame through Spark's API and feed to train XGBoost model in two lines of Scala code.

// %% [markdown]
// ### How to use this notebook
// This notebook basically provides an E2E workflow with which you can:
// - Building XGBoost jars
// - Deploying the jars to Azure Storage
// - Build a simple Boosting Tree algorithm to HDInsight using Spark Pipelines
// - Tune Hyper-Parameters for a boosting Tree model
// - Explain the Parameters of the model built
// - Save the model to Azure Storage

// %% [markdown]
// ### Building XGBoost from source code
// The following code snippet
//
// - installs the required libraries for building XGBoost
// - builds XGBoost using Maven
// - put the compiled jars to the default storage account of the HDInsight cluster
// - put the sample data to the default storage account of the HDInsight cluster
//
// The cell below is using the %%sh magic which will execute the code below as bash scripts in the head node.
//
// You might see something like this when building xgboost. This is expected and is part of the test case. The final test should pass.
//
//     Tracker started, with env={DMLC_NUM_SERVER=0, DMLC_TRACKER_URI=10.0.0.15, DMLC_TRACKER_PORT=9091, DMLC_NUM_WORKER=4}
//     17/08/14 22:41:34 ERROR Executor: Exception in task 3.0 in stage 0.0 (TID 3)
//     java.lang.RuntimeException: Worker exception.
//             at ml.dmlc.xgboost4j.scala.spark.RabitTrackerRobustnessSuite$$anonfun$1$$anonfun$2.apply(RabitTrackerRobustnessSuite.scala:72)
//             at ml.dmlc.xgboost4j.scala.spark.RabitTrackerRobustnessSuite$$anonfun$1$$anonfun$2.apply(RabitTrackerRobustnessSuite.scala:66)
//             at org.apache.spark.rdd.RDD$$anonfun$mapPartitions$1$$anonfun$apply$23.apply(RDD.scala:796)

// %%
%%sh
sudo apt-get update
sudo apt-get install -y maven git build-essential cmake python-setuptools
git clone --recursive https://github.com/dmlc/xgboost

#builds XGBoost using Maven
cd xgboost/jvm-packages
mvn -DskipTests=true install

#put the compiled packge to shared storage
#put to root folder for simplicity
hadoop fs -put -f xgboost4j-spark/target/xgboost4j-spark-0.7.jar /
hadoop fs -put -f xgboost4j/target/xgboost4j-0.7.jar /
hadoop fs -put -f xgboost4j-example/target/xgboost4j-example-0.7.jar /


#put the sample data to shared storage
hadoop fs -put -f ..//demo/data/agaricus.txt* /
// Out:
// [INFO] Scanning for projects...
// [WARNING]
// [WARNING] Some problems were encountered while building the effective model for ml.dmlc:xgboost4j:jar:0.7
// [WARNING] 'build.plugins.plugin.version' for org.codehaus.mojo:exec-maven-plugin is missing. @ line 54, column 19
// [WARNING]
// [WARNING] It is highly recommended to fix these problems because they threaten the stability of your build.
// [WARNING]
// [WARNING] For this reason, future Maven versions might no longer support building such malformed projects.
// [WARNING]
// [INFO] ------------------------------------------------------------------------
// [INFO] Reactor Build Order:
// [INFO]
// [INFO] xgboost-jvm
// [INFO] xgboost4j
// [INFO] xgboost4j-spark
// [INFO] xgboost4j-flink
// [INFO] xgboost4j-example
// [INFO]
// [INFO] ------------------------------------------------------------------------
// [INFO] Building xgboost-jvm 0.7
// [INFO] ------------------------------------------------------------------------
// [INFO]
// [INFO] --- scalastyle-maven-plugin:0.8.0:check (checkstyle) @ xgboost-jvm ---
// [WARNING] sourceDirectory is not specified or does not exist value=/var/lib/jupyter/xgboost/jvm-packages/src/main/scala
// [WARNING] testSourceDirectory is not specified or does not exist value=/var/lib/jupyter/xgboost/jvm-packages/src/test/scala
// Processed 0 file(s)
// Found 0 errors
// Found 0 warnings
// Found 0 infos
// Finished in 138 ms
// [INFO]
// [INFO] --- maven-checkstyle-plugin:2.17:check (checkstyle) @ xgboost-jvm ---
// [INFO]
// [INFO] --- scala-maven-plugin:3.2.2:compile (default) @ xgboost-jvm ---
// [WARNING]  Expected all dependencies to require Scala version: 2.11.8
// [WARNING]  ml.dmlc:xgboost-jvm:0.7 requires scala version: 2.11.8
// [WARNING]  org.scala-lang:scala-compiler:2.11.8 requires scala version: 2.11.8
// [WARNING]  org.scala-lang.modules:scala-xml_2.11:1.0.4 requires scala version: 2.11.4
// [WARNING] Multiple versions of scala libraries detected!
// [INFO] No sources to compile
// [INFO]
// [INFO] --- scala-maven-plugin:3.2.2:compile (scala-compile-first) @ xgboost-jvm ---
// [WARNING]  Expected all dependencies to require Scala version: 2.11.8
// [WARNING]  ml.dmlc:xgboost-jvm:0.7 requires scala version: 2.11.8
// [WARNING]  org.scala-lang:scala-compiler:2.11.8 requires scala version: 2.11.8
// [WARNING]  org.scala-lang.modules:scala-xml_2.11:1.0.4 requires scala version: 2.11.4
// [WARNING] Multiple versions of scala libraries detected!
// [INFO] No sources to compile
// [INFO]
// [INFO] --- scala-maven-plugin:3.2.2:add-source (scala-compile-first) @ xgboost-jvm ---
// [INFO] Add Source directory: /var/lib/jupyter/xgboost/jvm-packages/src/main/scala
// [INFO] Add Test Source directory: /var/lib/jupyter/xgboost/jvm-packages/src/test/scala
// [INFO]
// [INFO] --- scala-maven-plugin:3.2.2:compile (compile) @ xgboost-jvm ---
// [WARNING]  Expected all dependencies to require Scala version: 2.11.8
// [WARNING]  ml.dmlc:xgboost-jvm:0.7 requires scala version: 2.11.8
// [WARNING]  org.scala-lang:scala-compiler:2.11.8 requires scala version: 2.11.8
// [WARNING]  org.scala-lang.modules:scala-xml_2.11:1.0.4 requires scala version: 2.11.4
// [WARNING] Multiple versions of scala libraries detected!
// [INFO] No sources to compile
// [INFO]
// [INFO] --- scala-maven-plugin:3.2.2:testCompile (test-compile) @ xgboost-jvm ---
// [WARNING]  Expected all dependencies to require Scala version: 2.11.8
// [WARNING]  ml.dmlc:xgboost-jvm:0.7 requires scala version: 2.11.8
// [WARNING]  org.scala-lang:scala-compiler:2.11.8 requires scala version: 2.11.8
// [WARNING]  org.scala-lang.modules:scala-xml_2.11:1.0.4 requires scala version: 2.11.4
// [WARNING] Multiple versions of scala libraries detected!
// [INFO] No sources to compile
// [INFO]
// [INFO] --- scalatest-maven-plugin:1.0:test (test) @ xgboost-jvm ---
// [INFO] Tests are skipped.
// [INFO]
// [INFO] --- maven-assembly-plugin:2.6:single (make-assembly) @ xgboost-jvm ---
// [INFO] Assemblies have been skipped per configuration of the skipAssembly parameter.
// [INFO]
// [INFO] --- maven-source-plugin:3.0.1:jar-no-fork (attach-sources) @ xgboost-jvm ---
// [INFO]
// [INFO] --- maven-install-plugin:2.5.2:install (default-install) @ xgboost-jvm ---
// [INFO] Installing /var/lib/jupyter/xgboost/jvm-packages/pom.xml to /home/spark/.m2/repository/ml/dmlc/xgboost-jvm/0.7/xgboost-jvm-0.7.pom
// [INFO]
// [INFO] ------------------------------------------------------------------------
// [INFO] Building xgboost4j 0.7
// [INFO] ------------------------------------------------------------------------
// [INFO]
// [INFO] --- scalastyle-maven-plugin:0.8.0:check (checkstyle) @ xgboost4j ---
// Processed 14 file(s)
// Found 0 errors
// Found 0 warnings
// Found 0 infos
// Finished in 2148 ms
// [INFO]
// [INFO] --- maven-checkstyle-plugin:2.17:check (checkstyle) @ xgboost4j ---
// [INFO]
// [INFO] --- exec-maven-plugin:1.6.0:exec (native) @ xgboost4j ---
// building Java wrapper
// cd ..
// mkdir -p build
// cd build
// cmake .. -DUSE_S3:BOOL=OFF -DUSE_OPENMP:BOOL=ON -DPLUGIN_UPDATER_GPU:BOOL=OFF -DUSE_AZURE:BOOL=OFF -DUSE_HDFS:BOOL=OFF -DJVM_BINDINGS:BOOL=ON
// -- Configuring done
// -- Generating done
// -- Build files have been written to: /var/lib/jupyter/xgboost/build
// cmake --build . --config Release
// [  9%] Built target rabit
// [ 25%] Built target dmlccore
// [ 90%] Built target objxgboost
// [ 94%] Built target xgboost4j
// [ 98%] Built target runxgboost
// [100%] Built target xgboost
// cd demo/regression
// /usr/bin/anaconda/bin/python mapfeat.py
// /usr/bin/anaconda/bin/python mknfold.py machine.txt 1
// copying native library
// mkdir -p xgboost4j/src/main/resources/lib
// cp ../lib/libxgboost4j.so xgboost4j/src/main/resources/lib
// copying pure-Python tracker
// cp ../dmlc-core/tracker/dmlc_tracker/tracker.py xgboost4j/src/main/resources
// copying train/test files
// mkdir -p xgboost4j-spark/src/test/resources
// cd ../demo/regression
// /usr/bin/anaconda/bin/python mapfeat.py
// /usr/bin/anaconda/bin/python mknfold.py machine.txt 1
// cp ../demo/regression/machine.txt.test xgboost4j-spark/src/test/resources
// cp ../demo/regression/machine.txt.train xgboost4j-spark/src/test/resources
// cp ../demo/data/agaricus.txt.test xgboost4j-spark/src/test/resources
// cp ../demo/data/agaricus.txt.train xgboost4j-spark/src/test/resources
// [INFO]
// [INFO] --- maven-resources-plugin:2.6:resources (default-resources) @ xgboost4j ---
// [INFO] Using 'UTF-8' encoding to copy filtered resources.
// [INFO] Copying 2 resources
// [INFO]
// [INFO] --- scala-maven-plugin:3.2.2:compile (default) @ xgboost4j ---
// [WARNING]  Expected all dependencies to require Scala version: 2.11.8
// [WARNING]  com.typesafe.akka:akka-actor_2.11:2.3.11 requires scala version: 2.11.5
// [WARNING] Multiple versions of scala libraries detected!
// [INFO] Nothing to compile - all classes are up to date
// [INFO]
// [INFO] --- scala-maven-plugin:3.2.2:compile (scala-compile-first) @ xgboost4j ---
// [WARNING]  Expected all dependencies to require Scala version: 2.11.8
// [WARNING]  com.typesafe.akka:akka-actor_2.11:2.3.11 requires scala version: 2.11.5
// [WARNING] Multiple versions of scala libraries detected!
// [INFO] Nothing to compile - all classes are up to date
// [INFO]
// [INFO] --- scala-maven-plugin:3.2.2:add-source (scala-compile-first) @ xgboost4j ---
// [INFO] Add Source directory: /var/lib/jupyter/xgboost/jvm-packages/xgboost4j/src/main/scala
// [INFO] Add Test Source directory: /var/lib/jupyter/xgboost/jvm-packages/xgboost4j/src/test/scala
// [INFO]
// [INFO] --- maven-compiler-plugin:3.2:compile (default-compile) @ xgboost4j ---
// [INFO] Nothing to compile - all classes are up to date
// [INFO]
// [INFO] --- scala-maven-plugin:3.2.2:compile (compile) @ xgboost4j ---
// [WARNING]  Expected all dependencies to require Scala version: 2.11.8
// [WARNING]  com.typesafe.akka:akka-actor_2.11:2.3.11 requires scala version: 2.11.5
// [WARNING] Multiple versions of scala libraries detected!
// [INFO] Nothing to compile - all classes are up to date
// [INFO]
// [INFO] --- maven-resources-plugin:2.6:testResources (default-testResources) @ xgboost4j ---
// [INFO] Using 'UTF-8' encoding to copy filtered resources.
// [INFO] skip non existing resourceDirectory /var/lib/jupyter/xgboost/jvm-packages/xgboost4j/src/test/resources
// [INFO]
// [INFO] --- maven-compiler-plugin:3.2:testCompile (default-testCompile) @ xgboost4j ---
// [INFO] Nothing to compile - all classes are up to date
// [INFO]
// [INFO] --- scala-maven-plugin:3.2.2:testCompile (test-compile) @ xgboost4j ---
// [WARNING]  Expected all dependencies to require Scala version: 2.11.8
// [WARNING]  com.typesafe.akka:akka-actor_2.11:2.3.11 requires scala version: 2.11.5
// [WARNING] Multiple versions of scala libraries detected!
// [INFO] Nothing to compile - all classes are up to date
// [INFO]
// [INFO] --- maven-surefire-plugin:2.19.1:test (default-test) @ xgboost4j ---
//
// -------------------------------------------------------
//  T E S T S
// -------------------------------------------------------
// Running ml.dmlc.xgboost4j.scala.rabit.RabitTrackerConnectionHandlerTest
// Tests run: 4, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 1 sec - in ml.dmlc.xgboost4j.scala.rabit.RabitTrackerConnectionHandlerTest
// Running ml.dmlc.xgboost4j.java.DMatrixTest
// 5
// 5
// Tests run: 8, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 0.177 sec - in ml.dmlc.xgboost4j.java.DMatrixTest
// Running ml.dmlc.xgboost4j.java.BoosterImplTest
// [23:39:01] Tree method is selected to be 'hist', which uses a single updater grow_fast_histmaker.
// [0]	training-auc:0.958228
// [1]	training-auc:0.987161
// [2]	training-auc:0.993971
// [3]	training-auc:0.997779
// [4]	training-auc:0.998543
// [5]	training-auc:0.998960
// [6]	training-auc:0.998960
// [7]	training-auc:0.998960
// [8]	training-auc:0.999250
// [9]	training-auc:0.999365
// [23:39:02] Tree method is selected to be 'hist', which uses a single updater grow_fast_histmaker.
// [0]	training-auc:0.994714
// [1]	training-auc:0.998459
// [2]	training-auc:0.998459
// [3]	training-auc:0.998459
// [4]	training-auc:0.999977
// [5]	training-auc:0.999991
// [6]	training-auc:0.999991
// [7]	training-auc:0.999991
// [8]	training-auc:1.000000
// [9]	training-auc:1.000000
// [0]	test-error:0.042831	train-error:0.046522
// [1]	test-error:0.021726	train-error:0.022263
// [2]	test-error:0.006207	train-error:0.007063
// [3]	test-error:0.018001	train-error:0.015200
// [4]	test-error:0.006207	train-error:0.007063
// [0]	test-error:0.042831	train-error:0.046522
// [1]	test-error:0.021726	train-error:0.022263
// [2]	test-error:0.006207	train-error:0.007063
// [3]	test-error:0.018001	train-error:0.015200
// [4]	test-error:0.006207	train-error:0.007063
// [23:39:02] Tree method is selected to be 'hist', which uses a single updater grow_fast_histmaker.
// [0]	training-auc:0.958228
// [1]	training-auc:0.987161
// [2]	training-auc:0.993971
// [3]	training-auc:0.997779
// [4]	training-auc:0.998543
// [5]	training-auc:0.998960
// [6]	training-auc:0.998960
// [7]	training-auc:0.998960
// [8]	training-auc:0.999250
// [9]	training-auc:0.999365
// [23:39:02] Tree method is selected to be 'hist', which uses a single updater grow_fast_histmaker.
// [0]	test-auc:0.986255	training-auc:0.987112
// [1]	test-auc:0.998653	training-auc:0.997538
// [2]	test-auc:0.998958	training-auc:0.997675
// [3]	test-auc:0.999957	training-auc:0.998421
// [4]	test-auc:1.000000	training-auc:0.999880
// [5]	test-auc:1.000000	training-auc:0.999880
// [6]	test-auc:1.000000	training-auc:0.999935
// [7]	test-auc:1.000000	training-auc:1.000000
// [8]	test-auc:1.000000	training-auc:1.000000
// [9]	test-auc:1.000000	training-auc:1.000000
// [23:39:02] Tree method is selected to be 'hist', which uses a single updater grow_fast_histmaker.
// [0]	test-auc:0.994937	training-auc:0.994714
// [1]	test-auc:0.999972	training-auc:0.998459
// [2]	test-auc:0.999972	training-auc:0.998459
// [3]	test-auc:0.999972	training-auc:0.998459
// [4]	test-auc:1.000000	training-auc:0.999977
// [5]	test-auc:1.000000	training-auc:0.999991
// [6]	test-auc:1.000000	training-auc:0.999991
// [7]	test-auc:1.000000	training-auc:0.999991
// [8]	test-auc:1.000000	training-auc:1.000000
// [9]	test-auc:1.000000	training-auc:1.000000
// [0]	test-error:0.042831	train-error:0.046522
// [1]	test-error:0.021726	train-error:0.022263
// [2]	test-error:0.006207	train-error:0.007063
// [3]	test-error:0.018001	train-error:0.015200
// [4]	test-error:0.006207	train-error:0.007063
// [0]	test-error:0.042831	train-error:0.046522
// [1]	test-error:0.021726	train-error:0.022263
// [2]	test-error:0.006207	train-error:0.007063
// [3]	test-error:0.018001	train-error:0.015200
// [4]	test-error:0.006207	train-error:0.007063
// Tests run: 10, Failures: 0, Errors: 0, Skipped: 0, Time elapsed: 1.442 sec - in ml.dmlc.xgboost4j.java.BoosterImplTest
//
// Results :
//
// Tests run: 22, Failures: 0, Errors: 0, Skipped: 0
//
// [INFO]
// [INFO] --- scalatest-maven-plugin:1.0:test (test) @ xgboost4j ---
// [INFO] Tests are skipped.
// [INFO]
// [INFO] --- maven-jar-plugin:2.4:jar (default-jar) @ xgboost4j ---
// [INFO] Building jar: /var/lib/jupyter/xgboost/jvm-packages/xgboost4j/target/xgboost4j-0.7.jar
// [INFO]
// [INFO] --- maven-assembly-plugin:2.6:single (make-assembly) @ xgboost4j ---
// [INFO] Building jar: /var/lib/jupyter/xgboost/jvm-packages/xgboost4j/target/xgboost4j-0.7-jar-with-dependencies.jar
// [INFO]
// [INFO] --- maven-source-plugin:3.0.1:jar-no-fork (attach-sources) @ xgboost4j ---
// [INFO] Building jar: /var/lib/jupyter/xgboost/jvm-packages/xgboost4j/target/xgboost4j-0.7-sources.jar
// [INFO]
// [INFO] --- maven-install-plugin:2.5.2:install (default-install) @ xgboost4j ---
// [INFO] Installing /var/lib/jupyter/xgboost/jvm-packages/xgboost4j/target/xgboost4j-0.7.jar to /home/spark/.m2/repository/ml/dmlc/xgboost4j/0.7/xgboost4j-0.7.jar
// [INFO] Installing /var/lib/jupyter/xgboost/jvm-packages/xgboost4j/pom.xml to /home/spark/.m2/repository/ml/dmlc/xgboost4j/0.7/xgboost4j-0.7.pom
// [INFO] Installing /var/lib/jupyter/xgboost/jvm-packages/xgboost4j/target/xgboost4j-0.7-jar-with-dependencies.jar to /home/spark/.m2/repository/ml/dmlc/xgboost4j/0.7/xgboost4j-0.7-jar-with-dependencies.jar
// [INFO] Installing /var/lib/jupyter/xgboost/jvm-packages/xgboost4j/target/xgboost4j-0.7-sources.jar to /home/spark/.m2/repository/ml/dmlc/xgboost4j/0.7/xgboost4j-0.7-sources.jar
// [INFO]
// [INFO] ------------------------------------------------------------------------
// [INFO] Building xgboost4j-spark 0.7
// [INFO] ------------------------------------------------------------------------
// [INFO]
// [INFO] --- scalastyle-maven-plugin:0.8.0:check (checkstyle) @ xgboost4j-spark ---
// Processed 21 file(s)
// Found 0 errors
// Found 0 warnings
// Found 0 infos
// Finished in 690 ms
// [INFO]
// [INFO] --- maven-checkstyle-plugin:2.17:check (checkstyle) @ xgboost4j-spark ---
// [INFO]
// [INFO] --- maven-resources-plugin:2.6:resources (default-resources) @ xgboost4j-spark ---
// [INFO] Using 'UTF-8' encoding to copy filtered resources.
// [INFO] skip non existing resourceDirectory /var/lib/jupyter/xgboost/jvm-packages/xgboost4j-spark/src/main/resources
// [INFO]
// [INFO] --- scala-maven-plugin:3.2.2:compile (default) @ xgboost4j-spark ---
// [WARNING]  Expected all dependencies to require Scala version: 2.11.8
// [WARNING]  com.typesafe.akka:akka-actor_2.11:2.3.11 requires scala version: 2.11.5
// [WARNING] Multiple versions of scala libraries detected!
// [INFO] Nothing to compile - all classes are up to date
// [INFO]
// [INFO] --- scala-maven-plugin:3.2.2:compile (scala-compile-first) @ xgboost4j-spark ---
// [WARNING]  Expected all dependencies to require Scala version: 2.11.8
// [WARNING]  com.typesafe.akka:akka-actor_2.11:2.3.11 requires scala version: 2.11.5
// [WARNING] Multiple versions of scala libraries detected!
// [INFO] Nothing to compile - all classes are up to date
// [INFO]
// [INFO] --- scala-maven-plugin:3.2.2:add-source (scala-compile-first) @ xgboost4j-spark ---
// [INFO] Add Source directory: /var/lib/jupyter/xgboost/jvm-packages/xgboost4j-spark/src/main/scala
// [INFO] Add Test Source directory: /var/lib/jupyter/xgboost/jvm-packages/xgboost4j-spark/src/test/scala
// [INFO]
// [INFO] --- maven-compiler-plugin:3.2:compile (default-compile) @ xgboost4j-spark ---
// [INFO] Nothing to compile - all classes are up to date
// [INFO]
// [INFO] --- scala-maven-plugin:3.2.2:compile (compile) @ xgboost4j-spark ---
// [WARNING]  Expected all dependencies to require Scala version: 2.11.8
// [WARNING]  com.typesafe.akka:akka-actor_2.11:2.3.11 requires scala version: 2.11.5
// [WARNING] Multiple versions of scala libraries detected!
// [INFO] Nothing to compile - all classes are up to date
// [INFO]
// [INFO] --- maven-resources-plugin:2.6:testResources (default-testResources) @ xgboost4j-spark ---
// [INFO] Using 'UTF-8' encoding to copy filtered resources.
// [INFO] Copying 12 resources
// [INFO]
// [INFO] --- maven-compiler-plugin:3.2:testCompile (default-testCompile) @ xgboost4j-spark ---
// [INFO] Nothing to compile - all classes are up to date
// [INFO]
// [INFO] --- scala-maven-plugin:3.2.2:testCompile (test-compile) @ xgboost4j-spark ---
// [WARNING]  Expected all dependencies to require Scala version: 2.11.8
// [WARNING]  com.typesafe.akka:akka-actor_2.11:2.3.11 requires scala version: 2.11.5
// [WARNING] Multiple versions of scala libraries detected!
// [INFO] /var/lib/jupyter/xgboost/jvm-packages/xgboost4j-spark/src/test/scala:-1: info: compiling
// [INFO] Compiling 8 source files to /var/lib/jupyter/xgboost/jvm-packages/xgboost4j-spark/target/test-classes at 1503013152274
// [WARNING] warning: there were two feature warnings; re-run with -feature for details
// [WARNING] one warning found
// [INFO] prepare-compile in 0 s
// [INFO] compile in 12 s
// [INFO]
// [INFO] --- maven-surefire-plugin:2.19.1:test (default-test) @ xgboost4j-spark ---
// Downloading: https://repo.maven.apache.org/maven2/org/apache/maven/surefire/surefire-junit3/2.19.1/surefire-junit3-2.19.1.pom
// Downloaded: https://repo.maven.apache.org/maven2/org/apache/maven/surefire/surefire-junit3/2.19.1/surefire-junit3-2.19.1.pom (3 KB at 1.8 KB/sec)
// Downloading: https://repo.maven.apache.org/maven2/org/apache/maven/surefire/surefire-junit3/2.19.1/surefire-junit3-2.19.1.jar
// Downloaded: https://repo.maven.apache.org/maven2/org/apache/maven/surefire/surefire-junit3/2.19.1/surefire-junit3-2.19.1.jar (26 KB at 44.8 KB/sec)
//
// -------------------------------------------------------
//  T E S T S
// -------------------------------------------------------
//
// Results :
//
// Tests run: 0, Failures: 0, Errors: 0, Skipped: 0
//
// [INFO]
// [INFO] --- scalatest-maven-plugin:1.0:test (test) @ xgboost4j-spark ---
// [INFO] Tests are skipped.
// [INFO]
// [INFO] --- maven-jar-plugin:2.4:jar (default-jar) @ xgboost4j-spark ---
// [INFO] Building jar: /var/lib/jupyter/xgboost/jvm-packages/xgboost4j-spark/target/xgboost4j-spark-0.7.jar
// [INFO]
// [INFO] --- maven-assembly-plugin:2.6:single (make-assembly) @ xgboost4j-spark ---
// [INFO] Building jar: /var/lib/jupyter/xgboost/jvm-packages/xgboost4j-spark/target/xgboost4j-spark-0.7-jar-with-dependencies.jar
// [INFO]
// [INFO] --- maven-source-plugin:3.0.1:jar-no-fork (attach-sources) @ xgboost4j-spark ---
// [INFO] Building jar: /var/lib/jupyter/xgboost/jvm-packages/xgboost4j-spark/target/xgboost4j-spark-0.
0 KB/sec)
// Downloading: https://repo1.maven.org/maven2/com/thoughtworks/paranamer/paranamer/2.3/paranamer-2.3.jar
// Downloaded: https://repo1.maven.org/maven2/commons-lang/commons-lang/2.6/commons-lang-2.6.jar (278 KB at 115.8 KB/sec)
// Downloading: https://repo1.maven.org/maven2/org/xerial/snappy/snappy-java/1.0.5/snappy-java-1.0.5.jar
// Downloaded: https://repo1.maven.org/maven2/org/codehaus/jackson/jackson-core-asl/1.8.8/jackson-core-asl-1.8.8.jar (223 KB at 90.2 KB/sec)
// Downloading: https://repo1.maven.org/maven2/com/jcraft/jsch/0.1.42/jsch-0.1.42.jar
// Downloaded: https://repo1.maven.org/maven2/com/thoughtworks/paranamer/paranamer/2.3/paranamer-2.3.jar (29 KB at 11.1 KB/sec)
// Downloading: https://repo1.maven.org/maven2/commons-daemon/commons-daemon/1.0.13/commons-daemon-1.0.13.jar
// Downloaded: https://repo1.maven.org/maven2/org/codehaus/jackson/jackson-mapper-asl/1.8.8/jackson-mapper-asl-1.8.8.jar (653 KB at 233.4 KB/sec)
// Downloading: https://repo1.maven.org/maven2/javax/xml/bind/jaxb-api/2.2.2/jaxb-api-2.2.2.jar
// Downloaded: https://repo1.maven.org/maven2/com/jcraft/jsch/0.1.42/jsch-0.1.42.jar (182 KB at 64.2 KB/sec)
// Downloading: https://repo1.maven.org/maven2/javax/xml/stream/stax-api/1.0-2/stax-api-1.0-2.jar
// Downloaded: https://repo1.maven.org/maven2/org/xerial/snappy/snappy-java/1.0.5/snappy-java-1.0.5.jar (1223 KB at 429.4 KB/sec)
// Downloading: https://repo1.maven.org/maven2/javax/activation/activation/1.1/activation-1.1.jar
// Downloaded: https://repo1.maven.org/maven2/commons-daemon/commons-daemon/1.0.13/commons-daemon-1.0.13.jar (24 KB at 8.0 KB/sec)
// Downloading: https://repo1.maven.org/maven2/commons-collections/commons-collections/3.2.2/commons-collections-3.2.2.jar
// Downloaded: https://repo1.maven.org/maven2/javax/xml/bind/jaxb-api/2.2.2/jaxb-api-2.2.2.jar (103 KB at 32.3 KB/sec)
// Downloading: https://repo1.maven.org/maven2/com/twitter/chill_2.11/0.5.2/chill_2.11-0.5.2.jar
// Downloaded: https://repo1.maven.org/maven2/javax/xml/stream/stax-api/1.0-2/stax-api-1.0-2.jar (23 KB at 7.2 KB/sec)
// Downloading: https://repo1.maven.org/maven2/com/twitter/chill-java/0.5.2/chill-java-0.5.2.jar
// Downloaded: https://repo1.maven.org/maven2/javax/activation/activation/1.1/activation-1.1.jar (62 KB at 19.2 KB/sec)
// Downloading: https://repo1.maven.org/maven2/org/apache/flink/flink-java_2.11/0.10.2/flink-java_2.11-0.10.2.jar
// Downloaded: https://repo1.maven.org/maven2/commons-collections/commons-collections/3.2.2/commons-collections-3.2.2.jar (575 KB at 163.8 KB/sec)
// Downloading: https://repo1.maven.org/maven2/org/apache/avro/avro/1.7.6/avro-1.7.6.jar
// Downloaded: https://repo1.maven.org/maven2/com/twitter/chill-java/0.5.2/chill-java-0.5.2.jar (47 KB at 13.2 KB/sec)
// Downloading: https://repo1.maven.org/maven2/com/twitter/chill-avro_2.11/0.5.2/chill-avro_2.11-0.5.2.jar
// Downloaded: https://repo1.maven.org/maven2/org/apache/flink/flink-shaded-hadoop2_2.11/0.10.2/flink-shaded-hadoop2_2.11-0.10.2.jar (18072 KB at 5041.0 KB/sec)
// Downloading: https://repo1.maven.org/maven2/com/twitter/chill-bijection_2.11/0.5.2/chill-bijection_2.11-0.5.2.jar
// Downloaded: https://repo1.maven.org/maven2/com/twitter/chill_2.11/0.5.2/chill_2.11-0.5.2.jar (216 KB at 57.4 KB/sec)
// Downloading: https://repo1.maven.org/maven2/com/twitter/bijection-core_2.11/0.7.2/bijection-core_2.11-0.7.2.jar
// Downloaded: https://repo1.maven.org/maven2/org/apache/flink/flink-java_2.11/0.10.2/flink-java_2.11-0.10.2.jar (3338 KB at 879.4 KB/sec)
// Downloading: https://repo1.maven.org/maven2/com/twitter/bijection-avro_2.11/0.7.2/bijection-avro_2.11-0.7.2.jar
// Downloaded: https://repo1.maven.org/maven2/com/twitter/chill-avro_2.11/0.5.2/chill-avro_2.11-0.5.2.jar (4 KB at 0.9 KB/sec)
// Downloading: https://repo1.maven.org/maven2/de/javakaffee/kryo-serializers/0.27/kryo-serializers-0.27.jar
// Downloaded: https://repo1.maven.org/maven2/org/apache/avro/avro/1.7.6/avro-1.7.6.jar (416 KB at 106.6 KB/sec)
// Downloading: https://repo1.maven.org/maven2/joda-time/joda-time/2.5/joda-time-2.5.jar
// Downloaded: https://repo1.maven.org/maven2/com/twitter/chill-bijection_2.11/0.5.2/chill-bijection_2.11-0.5.2.jar (21 KB at 5.2 KB/sec)
// Downloading: https://repo1.maven.org/maven2/org/joda/joda-convert/1.7/joda-convert-1.7.jar
// Downloaded: https://repo1.maven.org/maven2/com/twitter/bijection-avro_2.11/0.7.2/bijection-avro_2.11-0.7.2.jar (26 KB at 6.2 KB/sec)
// Downloading: https://repo1.maven.org/maven2/org/apache/commons/commons-math3/3.5/commons-math3-3.5.jar
// Downloaded: https://repo1.maven.org/maven2/de/javakaffee/kryo-serializers/0.27/kryo-serializers-0.27.jar (69 KB at 16.2 KB/sec)
// Downloading: https://repo1.maven.org/maven2/org/apache/flink/flink-optimizer_2.11/0.10.2/flink-optimizer_2.11-0.10.2.jar
// Downloaded: https://repo1.maven.org/maven2/org/joda/joda-convert/1.7/joda-convert-1.7.jar (101 KB at 23.4 KB/sec)
// Downloading: https://repo1.maven.org/maven2/org/slf4j/slf4j-api/1.7.7/slf4j-api-1.7.7.jar
// Downloaded: https://repo1.maven.org/maven2/joda-time/joda-time/2.5/joda-time-2.5.jar (575 KB at 133.3 KB/sec)
// Downloading: https://repo1.maven.org/maven2/org/slf4j/slf4j-log4j12/1.7.7/slf4j-log4j12-1.7.7.jar
// ...
// Downloading: https://repo1.maven.org/maven2/org/eclipse/jetty/jetty-util/8.0.0.M1/jetty-util-8.0.0.M1.jar
// Downloaded: https://repo1.maven.org/maven2/org/eclipse/jetty/jetty-continuation/8.0.0.M1/jetty-continuation-8.0.0.M1.jar (21 KB at 3.1 KB/sec)
// Downloading: https://repo1.maven.org/maven2/org/eclipse/jetty/jetty-security/8.0.0.M1/jetty-security-8.0.0.M1.jar
// Downloaded: https://repo1.maven.org/maven2/org/mortbay/jetty/servlet-api/3.0.20100224/servlet-api-3.0.20100224.jar (206 KB at 30.3 KB/sec)
// Downloading: https://repo1.maven.org/maven2/org/eclipse/jetty/jetty-servlet/8.0.0.M1/jetty-servlet-8.0.0.M1.jar
// Downloaded: https://repo1.maven.org/maven2/org/eclipse/jetty/jetty-http/8.0.0.M1/jetty-http-8.0.0.M1.jar (101 KB at 14.7 KB/sec)
// Downloading: https://repo1.maven.org/maven2/commons-fileupload/commons-fileupload/1.3.1/commons-fileupload-1.3.1.jar
// Downloaded: https://repo1.maven.org/maven2/org/eclipse/jetty/jetty-io/8.0.0.M1/jetty-io-8.0.0.M1.jar (80 KB at 11.4 KB/sec)
// Downloading: https://repo1.maven.org/maven2/commons-io/commons-io/2.4/commons-io-2.4.jar
// Downloaded: https://repo1.maven.org/maven2/org/eclipse/jetty/jetty-util/8.0.0.M1/jetty-util-8.0.0.M1.jar (201 KB at 28.6 KB/sec)
// Downloading: https://repo1.maven.org/maven2/org/apache/flink/flink-ml_2.11/0.10.2/flink-ml_2.11-0.10.2.jar
// Downloaded: https://repo1.maven.org/maven2/org/eclipse/jetty/jetty-security/8.0.0.M1/jetty-security-8.0.0.M1.jar (68 KB at 9.5 KB/sec)
// Downloading: https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.11.2/breeze_2.11-0.11.2.jar
// Downloaded: https://repo1.maven.org/maven2/org/eclipse/jetty/jetty-servlet/8.0.0.M1/jetty-servlet-8.0.0.M1.jar (80 KB at 11.1 KB/sec)
// Downloading: https://repo1.maven.org/maven2/org/scalanlp/breeze-macros_2.11/0.11.2/breeze-macros_2.11-0.11.2.jar
// Downloaded: https://repo1.maven.org/maven2/commons-fileupload/commons-fileupload/1.3.1/commons-fileupload-1.3.1.jar (68 KB at 9.3 KB/sec)
// Downloading: https://repo1.maven.org/maven2/junit/junit/4.8.2/junit-4.8.2.jar
// Downloaded: https://repo1.maven.org/maven2/commons-io/commons-io/2.4/commons-io-2.4.jar (181 KB at 24.6 KB/sec)
// Downloaded: https://repo1.maven.org/maven2/org/apache/flink/flink-ml_2.11/0.10.2/flink-ml_2.11-0.10.2.jar (938 KB at 125.8 KB/sec)
// Downloaded: https://repo1.maven.org/maven2/org/scalanlp/breeze-macros_2.11/0.11.2/breeze-macros_2.11-0.11.2.jar (133 KB at 17.7 KB/sec)
// Downloaded: https://repo1.maven.org/maven2/junit/junit/4.8.2/junit-4.8.2.jar (232 KB at 30.4 KB/sec)
// Downloaded: https://repo1.maven.org/maven2/org/scalanlp/breeze_2.11/0.11.2/breeze_2.11-0.11.2.jar (13134 KB at 1567.6 KB/sec)
// [INFO]
// [INFO] --- scalastyle-maven-plugin:0.8.0:check (checkstyle) @ xgboost4j-flink ---
// [WARNING] testSourceDirectory is not specified or does not exist value=/var/lib/jupyter/xgboost/jvm-packages/xgboost4j-flink/src/test/scala
// Processed 2 file(s)
// Found 0 errors
// Found 0 warnings
// Found 0 infos
// Finished in 61 ms
// [INFO]
// [INFO] --- maven-checkstyle-plugin:2.17:check (checkstyle) @ xgboost4j-flink ---
// [INFO]
// [INFO] --- maven-resources-plugin:2.6:resources (default-resources) @ xgboost4j-flink ---
// [INFO] Using 'UTF-8' encoding to copy filtered resources.
// [INFO] skip non existing resourceDirectory /var/lib/jupyter/xgboost/jvm-packages/xgboost4j-flink/src/main/resources
// [INFO]
// [INFO] --- scala-maven-plugin:3.2.2:compile (default) @ xgboost4j-flink ---
// [WARNING]  Expected all dependencies to require Scala version: 2.11.8
// [WARNING]  com.typesafe.akka:akka-actor_2.11:2.3.11 requires scala version: 2.11.5
// [WARNING] Multiple versions of scala libraries detected!
// [INFO] /var/lib/jupyter/xgboost/jvm-packages/xgboost4j-flink/src/main/scala:-1: info: compiling
// [INFO] Compiling 2 source files to /var/lib/jupyter/xgboost/jvm-packages/xgboost4j-flink/target/classes at 1503013213039
// [INFO] prepare-compile in 0 s
// [INFO] compile in 4 s
// [INFO]
// [INFO] --- scala-maven-plugin:3.2.2:compile (scala-compile-first) @ xgboost4j-flink ---
// [WARNING]  Expected all dependencies to require Scala version: 2.11.8
// [WARNING]  com.typesafe.akka:akka-actor_2.11:2.3.11 requires scala version: 2.11.5
// [WARNING] Multiple versions of scala libraries detected!
// [INFO] Nothing to compile - all classes are up to date
// [INFO]
// [INFO] --- scala-maven-plugin:3.2.2:add-source (scala-compile-first) @ xgboost4j-flink ---
// [INFO] Add Source directory: /var/lib/jupyter/xgboost/jvm-packages/xgboost4j-flink/src/main/scala
// [INFO] Add Test Source directory: /var/lib/jupyter/xgboost/jvm-packages/xgboost4j-flink/src/test/scala
// [INFO]
// [INFO] --- maven-compiler-plugin:3.2:compile (default-compile) @ xgboost4j-flink ---
// [INFO] Nothing to compile - all classes are up to date
// [INFO]
// [INFO] --- scala-maven-plugin:3.2.2:compile (compile) @ xgboost4j-flink ---
// [WARNING]  Expected all dependencies to require Scala version: 2.11.8
// [WARNING]  com.typesafe.akka:akka-actor_2.11:2.3.11 requires scala version: 2.11.5
// [WARNING] Multiple versions of scala libraries detected!
// [INFO] Nothing to compile - all classes are up to date
// [INFO]
// [INFO] --- maven-resources-plugin:2.6:testResources (default-testResources) @ xgboost4j-flink ---
// [INFO] Using 'UTF-8' encoding to copy filtered resources.
// [INFO] skip non existing resourceDirectory /var/lib/jupyter/xgboost/jvm-packages/xgboost4j-flink/src/test/resources
// [INFO]
// [INFO] --- maven-compiler-plugin:3.2:testCompile (default-testCompile) @ xgboost4j-flink ---
// [INFO] No sources to compile
// [INFO]
// [INFO] --- scala-maven-plugin:3.2.2:testCompile (test-compile) @ xgboost4j-flink ---
// [WARNING]  Expected all dependencies to require Scala version: 2.11.8
// [WARNING]  com.typesafe.akka:akka-actor_2.11:2.3.11 requires scala version: 2.11.5
// [WARNING] Multiple versions of scala libraries detected!
// [INFO] No sources to compile
// [INFO]
// [INFO] --- maven-surefire-plugin:2.19.1:test (default-test) @ xgboost4j-flink ---
// [INFO] No tests to run.
// [INFO]
// [INFO] --- scalatest-maven-plugin:1.0:test (test) @ xgboost4j-flink ---
// [INFO] Tests are skipped.
// [INFO]
// [INFO] --- maven-jar-plugin:2.4:jar (default-jar) @ xgboost4j-flink ---
// [INFO] Building jar: /var/lib/jupyter/xgboost/jvm-packages/xgboost4j-flink/target/xgboost4j-flink-0.7.jar
// [INFO]
// [INFO] --- maven-assembly-plugin:2.6:single (make-assembly) @ xgboost4j-flink ---
// [INFO] Building jar: /var/lib/jupyter/xgboost/jvm-packages/xgboost4j-flink/target/xgboost4j-flink-0.7-jar-with-dependencies.jar
// [INFO]
// [INFO] --- maven-source-plugin:3.0.1:jar-no-fork (attach-sources) @ xgboost4j-flink ---
// [INFO] Building jar: /var/lib/jupyter/xgboost/jvm-packages/xgboost4j-flink/target/xgboost4j-flink-0.7-sources.jar
// [INFO]
// [INFO] --- maven-install-plugin:2.5.2:install (default-install) @ xgboost4j-flink ---
// [INFO] Installing /var/lib/jupyter/xgboost/jvm-packages/xgboost4j-flink/target/xgboost4j-flink-0.7.jar to /home/spark/.m2/repository/ml/dmlc/xgboost4j-flink/0.7/xgboost4j-flink-0.7.jar
// [INFO] Installing /var/lib/jupyter/xgboost/jvm-packages/xgboost4j-flink/pom.xml to /home/spark/.m2/repository/ml/dmlc/xgboost4j-flink/0.7/xgboost4j-flink-0.7.pom
// [INFO] Installing /var/lib/jupyter/xgboost/jvm-packages/xgboost4j-flink/target/xgboost4j-flink-0.7-jar-with-dependencies.jar to /home/spark/.m2/repository/ml/dmlc/xgboost4j-flink/0.7/xgboost4j-flink-0.7-jar-with-dependencies.jar
// [INFO] Installing /var/lib/jupyter/xgboost/jvm-packages/xgboost4j-flink/target/xgboost4j-flink-0.7-sources.jar to /home/spark/.m2/repository/ml/dmlc/xgboost4j-flink/0.7/xgboost4j-flink-0.7-sources.jar
// [INFO]
// [INFO] ------------------------------------------------------------------------
// [INFO] Building xgboost4j-example 0.7
// [INFO] ------------------------------------------------------------------------
// [INFO]
// [INFO] --- scalastyle-maven-plugin:0.8.0:check (checkstyle) @ xgboost4j-example ---
// [WARNING] testSourceDirectory is not specified or does not exist value=/var/lib/jupyter/xgboost/jvm-packages/xgboost4j-example/src/test/scala
// Processed 13 file(s)
// Found 0 errors
// Found 0 warnings
// Found 0 infos
// Finished in 257 ms
// [INFO]
// [INFO] --- maven-checkstyle-plugin:2.17:check (checkstyle) @ xgboost4j-example ---
// [INFO]
// [INFO] --- maven-resources-plugin:2.6:resources (default-resources) @ xgboost4j-example ---
// [INFO] Using 'UTF-8' encoding to copy filtered resources.
// [INFO] skip non existing resourceDirectory /var/lib/jupyter/xgboost/jvm-packages/xgboost4j-example/src/main/resources
// [INFO]
// [INFO] --- scala-maven-plugin:3.2.2:compile (default) @ xgboost4j-example ---
// [WARNING]  Expected all dependencies to require Scala version: 2.11.8
// [WARNING]  com.typesafe.akka:akka-actor_2.11:2.3.11 requires scala version: 2.11.5
// [WARNING] Multiple versions of scala libraries detected!
// [INFO] /var/lib/jupyter/xgboost/jvm-packages/xgboost4j-example/src/main/java:-1: info: compiling
// [INFO] /var/lib/jupyter/xgboost/jvm-packages/xgboost4j-example/src/main/scala:-1: info: compiling
// [INFO] Compiling 23 source files to /var/lib/jupyter/xgboost/jvm-packages/xgboost4j-example/target/classes at 1503013230293
// [WARNING] /var/lib/jupyter/xgboost/jvm-packages/xgboost4j-example/src/main/scala/ml/dmlc/xgboost4j/scala/example/PredictLeafIndices.scala:19: warning: imported `util' is permanently hidden by definition of package util in package example
// [WARNING] import java.util
// [WARNING]             ^
// [WARNING] warning: there was one deprecation warning; re-run with -deprecation for details
// [WARNING] two warnings found
// [INFO] prepare-compile in 0 s
// [INFO] compile in 12 s
// [INFO]
// [INFO] --- scala-maven-plugin:3.2.2:compile (scala-compile-first) @ xgboost4j-example ---
// [WARNING]  Expected all dependencies to require Scala version: 2.11.8
// [WARNING]  com.typesafe.akka:akka-actor_2.11:2.3.11 requires scala version: 2.11.5
// [WARNING] Multiple versions of scala libraries detected!
// [INFO] Nothing to compile - all classes are up to date
// [INFO]
// [INFO] --- scala-maven-plugin:3.2.2:add-source (scala-compile-first) @ xgboost4j-example ---
// [INFO] Add Source directory: /var/lib/jupyter/xgboost/jvm-packages/xgboost4j-example/src/main/scala
// [INFO] Add Test Source directory: /var/lib/jupyter/xgboost/jvm-packages/xgboost4j-example/src/test/scala
// [INFO]
// [INFO] --- maven-compiler-plugin:3.2:compile (default-compile) @ xgboost4j-example ---
// [INFO] Changes detected - recompiling the module!
// [INFO] Compiling 10 source files to /var/lib/jupyter/xgboost/jvm-packages/xgboost4j-example/target/classes
// [INFO] /var/lib/jupyter/xgboost/jvm-packages/xgboost4j-example/src/main/java/ml/dmlc/xgboost4j/java/example/BasicWalkThrough.java: /var/lib/jupyter/xgboost/jvm-packages/xgboost4j-example/src/main/java/ml/dmlc/xgboost4j/java/example/BasicWalkThrough.java uses or overrides a deprecated API.
// [INFO] /var/lib/jupyter/xgboost/jvm-packages/xgboost4j-example/src/main/java/ml/dmlc/xgboost4j/java/example/BasicWalkThrough.java: Recompile with -Xlint:deprecation for details.
// [INFO]
// [INFO] --- scala-maven-plugin:3.2.2:compile (compile) @ xgboost4j-example ---
// [WARNING]  Expected all dependencies to require Scala version: 2.11.8
// [WARNING]  com.typesafe.akka:akka-actor_2.11:2.3.11 requires scala version: 2.11.5
// [WARNING] Multiple versions of scala libraries detected!
// [INFO] /var/lib/jupyter/xgboost/jvm-packages/xgboost4j-example/src/main/java:-1: info: compiling
// [INFO] /var/lib/jupyter/xgboost/jvm-packages/xgboost4j-example/src/main/scala:-1: info: compiling
// [INFO] /var/lib/jupyter/xgboost/jvm-packages/xgboost4j-example/target/generated-sources/annotations:-1: info: compiling
// [INFO] Compiling 23 source files to /var/lib/jupyter/xgboost/jvm-packages/xgboost4j-example/target/classes at 1503013244774
// [WARNING] /var/lib/jupyter/xgboost/jvm-packages/xgboost4j-example/src/main/scala/ml/dmlc/xgboost4j/scala/example/PredictLeafIndices.scala:19: warning: imported `util' is permanently hidden by definition of package util in package example
// [WARNING] import java.util
// [WARNING]             ^
// [WARNING] warning: there was one deprecation warning; re-run with -deprecation for details
// [WARNING] two warnings found
// [INFO] prepare-compile in 0 s
// [INFO] compile in 8 s
// [INFO]
// [INFO] --- maven-resources-plugin:2.6:testResources (default-testResources) @ xgboost4j-example ---
// [INFO] Using 'UTF-8' encoding to copy filtered resources.
// [INFO] skip non existing resourceDirectory /var/lib/jupyter/xgboost/jvm-packages/xgboost4j-example/src/test/resources
// [INFO]
// [INFO] --- maven-compiler-plugin:3.2:testCompile (default-testCompile) @ xgboost4j-example ---
// [INFO] No sources to compile
// [INFO]
// [INFO] --- scala-maven-plugin:3.2.2:testCompile (test-compile) @ xgboost4j-example ---
// [WARNING]  Expected all dependencies to require Scala version: 2.11.8
// [WARNING]  com.typesafe.akka:akka-actor_2.11:2.3.11 requires scala version: 2.11.5
// [WARNING] Multiple versions of scala libraries detected!
// [INFO] No sources to compile
// [INFO]
// [INFO] --- maven-surefire-plugin:2.19.1:test (default-test) @ xgboost4j-example ---
// [INFO] No tests to run.
// [INFO]
// [INFO] --- scalatest-maven-plugin:1.0:test (test) @ xgboost4j-example ---
// [INFO] Tests are skipped.
// [INFO]
// [INFO] --- maven-jar-plugin:2.4:jar (default-jar) @ xgboost4j-example ---
// [INFO] Building jar: /var/lib/jupyter/xgboost/jvm-packages/xgboost4j-example/target/xgboost4j-example-0.7.jar
// [INFO]
// [INFO] --- maven-assembly-plugin:2.6:single (make-assembly) @ xgboost4j-example ---
// [INFO] Building jar: /var/lib/jupyter/xgboost/jvm-packages/xgboost4j-example/target/xgboost4j-example-0.7-jar-with-dependencies.jar
// [INFO]
// [INFO] --- maven-source-plugin:3.0.1:jar-no-fork (attach-sources) @ xgboost4j-example ---
// [INFO] Building jar: /var/lib/jupyter/xgboost/jvm-packages/xgboost4j-example/target/xgboost4j-example-0.7-sources.jar
// [INFO]
// [INFO] --- maven-install-plugin:2.5.2:install (default-install) @ xgboost4j-example ---
// [INFO] Installing /var/lib/jupyter/xgboost/jvm-packages/xgboost4j-example/target/xgboost4j-example-0.7.jar to /home/spark/.m2/repository/ml/dmlc/xgboost4j-example/0.7/xgboost4j-example-0.7.jar
// [INFO] Installing /var/lib/jupyter/xgboost/jvm-packages/xgboost4j-example/pom.xml to /home/spark/.m2/repository/ml/dmlc/xgboost4j-example/0.7/xgboost4j-example-0.7.pom
// [INFO] Installing /var/lib/jupyter/xgboost/jvm-packages/xgboost4j-example/target/xgboost4j-example-0.7-jar-with-dependencies.jar to /home/spark/.m2/repository/ml/dmlc/xgboost4j-example/0.7/xgboost4j-example-0.7-jar-with-dependencies.jar
// [INFO] Installing /var/lib/jupyter/xgboost/jvm-packages/xgboost4j-example/target/xgboost4j-example-0.7-sources.jar to /home/spark/.m2/repository/ml/dmlc/xgboost4j-example/0.7/xgboost4j-example-0.7-sources.jar
// [INFO] ------------------------------------------------------------------------
// [INFO] Reactor Summary:
// [INFO]
// [INFO] xgboost-jvm ........................................ SUCCESS [  5.092 s]
// [INFO] xgboost4j .......................................... SUCCESS [ 14.209 s]
// [INFO] xgboost4j-spark .................................... SUCCESS [ 22.811 s]
// [INFO] xgboost4j-flink .................................... SUCCESS [ 58.204 s]
// [INFO] xgboost4j-example .................................. SUCCESS [ 33.197 s]
// [INFO] ------------------------------------------------------------------------
// [INFO] BUILD SUCCESS
// [INFO] ------------------------------------------------------------------------
// [INFO] Total time: 02:13 min
// [INFO] Finished at: 2017-08-17T23:41:02+00:00
// [INFO] Final Memory: 448M/2357M
// [INFO] ------------------------------------------------------------------------
// sudo: no tty present and no askpass program specified
// sudo: no tty present and no askpass program specified
// fatal: destination path 'xgboost' already exists and is not an empty directory.
// Aug 17, 2017 11:39:02 PM ml.dmlc.xgboost4j.java.XGBoost crossValidation
// INFO: [0]	cv-test-error:0.014439	cv-train-error:0.014431
// Aug 17, 2017 11:39:02 PM ml.dmlc.xgboost4j.java.XGBoost crossValidation
// INFO: [1]	cv-test-error:0.001229	cv-train-error:0.001228

// %% [markdown]
// ### Start a Spark session with XGBoost4J-Spark library loaded
// After putting the jars and the files to the Azure Storage, which is shared across all the HDInsight nodes, the next step is to start a Spark session and call the XGBoost libraries.
//
// In the configure cell below, first we need to load those jar files to the Spark session, so we can use XGBoost APIs in this Jupyter Notebook.
//
// We also need to exclude a few spark jars because there are some conflicts between Livy (which is the REST API used on HDInsight to execute Spark code), and XGBoost.

// %%
%%configure -f
{ "jars": ["wasb:///xgboost4j-spark-0.7.jar", "wasb:///xgboost4j-0.7.jar", "wasb:///xgboost4j-example-0.7.jar"],
  "conf": {
    "spark.jars.excludes": "org.scala-lang:scala-reflect:2.11.8,org.scala-lang:scala-compiler:2.11.8,org.scala-lang:scala-library:2.11.8"
   }
}
// Out:
// Current session configs: <tt>{u'jars': [u'wasb:///xgboost4j-spark-0.7.jar', u'wasb:///xgboost4j-0.7.jar', u'wasb:///xgboost4j-example-0.7.jar'], u'kind': 'spark', u'conf': {u'spark.jars.excludes': u'org.scala-lang:scala-reflect:2.11.8,org.scala-lang:scala-compiler:2.11.8,org.scala-lang:scala-library:2.11.8'}}</tt><br>
// No active sessions.

// %% [markdown]
// ### Import XGBoost and Spark Packages
// We then import the XGBoost packages and start a Spark application

// %%
import ml.dmlc.xgboost4j.scala.Booster
import ml.dmlc.xgboost4j.scala.spark.XGBoost
import org.apache.spark.sql.SparkSession
import org.apache.spark.SparkConf
import org.apache.spark.ml.{Pipeline, PipelineModel}
import org.apache.spark.ml.classification.LogisticRegression
import org.apache.spark.ml.feature.{HashingTF, Tokenizer}
import org.apache.spark.ml.linalg.Vector
import org.apache.spark.sql.Row
import ml.dmlc.xgboost4j.scala.spark.{XGBoostEstimator, XGBoost}
// Out:
// Starting Spark application
// <table>
// <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>Current session?</th></tr><tr><td>2</td><td>application_1502756750987_0006</td><td>spark</td><td>idle</td><td><a target="_blank" href="http://hn1-xiaoyz.znlyh0it2tzuza0r3wrc11atlh.ix.internal.cloudapp.net:8088/proxy/application_1502756750987_0006/">Link</a></td><td><a target="_blank" href="http://10.0.0.6:30060/node/containerlogs/container_1502756750987_0006_01_000001/livy">Link</a></td><td>✔</td></tr></table>
// SparkSession available as 'spark'.
// import ml.dmlc.xgboost4j.scala.spark.{XGBoostEstimator, XGBoost}

// %% [markdown]
// ### Train a simple XGBoost model
// We read data from the default BLOB storage account. The data is already put there if you run the %%sh cell above. But you can also get the data from [XGBoost repo](https://github.com/dmlc/xgboost/tree/master/demo/data).

// %%
// create training and testing dataframes
val inputTrainPath = "wasb:///agaricus.txt.train"
val inputTestPath = "wasb:///agaricus.txt.test"
val outputModelPath = "wasb:///XGBoostModelOutput"
val numWorkers = 4

// number of iterations
val numRound = 100

// build dataset
val trainDF = spark.sqlContext.read.format("libsvm").load(inputTrainPath)
val testDF = spark.sqlContext.read.format("libsvm").load(inputTestPath)
// start training
val paramMap = List(
  "eta" -> 0.1f,
  "max_depth" -> 6,
  "objective" -> "binary:logistic").toMap

val xgboostModel = XGBoost.trainWithDataFrame(
  trainDF, paramMap, numRound, nWorkers = numWorkers, useExternalMemory = true)
// Out:
// xgboostModel: ml.dmlc.xgboost4j.scala.spark.XGBoostModel = XGBoostClassificationModel_3515d47ea760

// %%
// construct the pipeline       
val pipeline = new Pipeline().setStages(Array(new XGBoostEstimator(Map[String, Any]("num_rounds" -> 100))))
// use the transformed dataframe as training dataset
val xgboostModelPipeLine = pipeline.fit(trainDF)

// predict with the trained model
val xgBoostModelPipelineTransform = xgboostModelPipeLine.transform(testDF)


xgBoostModelPipelineTransform.show()
// Out:
// +-----+--------------------+----------+
// |label|            features|prediction|
// +-----+--------------------+----------+
// |  0.0|(126,[0,8,18,20,2...|  0.350358|
// |  1.0|(126,[2,8,18,20,2...|0.64995027|
// |  0.0|(126,[0,8,19,20,2...|  0.350358|
// |  0.0|(126,[2,8,18,20,2...|  0.350358|
// |  0.0|(126,[3,6,10,21,2...|0.35038674|
// |  0.0|(126,[2,9,19,20,2...|0.35384613|
// |  1.0|(126,[2,8,10,20,2...|0.64995027|
// |  0.0|(126,[0,8,19,20,2...|  0.350358|
// |  1.0|(126,[2,8,18,20,2...|0.64995027|
// |  0.0|(126,[3,8,19,20,2...| 0.3509434|
// |  1.0|(126,[2,8,10,20,2...|0.64995027|
// |  0.0|(126,[0,8,19,20,2...|  0.350358|
// |  0.0|(126,[3,6,13,21,2...|0.35038674|
// |  0.0|(126,[0,8,18,20,2...|  0.350358|
// |  0.0|(126,[3,9,10,21,2...|0.35038674|
// |  0.0|(126,[3,8,19,20,2...| 0.3509434|
// |  0.0|(126,[0,9,19,20,2...|  0.350358|
// |  1.0|(126,[2,8,10,20,2...|0.64995027|
// |  0.0|(126,[5,6,10,21,2...|0.35038674|
// |  0.0|(126,[2,9,19,20,2...|  0.350358|
// +-----+--------------------+----------+
// only showing top 20 rows

// %% [markdown]
// ### Tune Hyper Parameters for your XGBoost Model using Spark
// Transform the test data and look at the results

// %%
import scala.collection.mutable
import scala.collection.mutable.ListBuffer
import org.apache.spark.ml.tuning._
import org.apache.spark.ml.evaluation.RegressionEvaluator

val xgboostParam = new mutable.HashMap[String, Any]()
xgboostParam += "eta" -> 0.1
xgboostParam += "max_depth" -> 6
xgboostParam += "silent" -> 1
xgboostParam += "ntreelimit" -> 1000
xgboostParam += "objective" -> "reg:linear"
xgboostParam += "subsample" -> 0.8
xgboostParam += "num_round" -> 100

val xgbEstimator = new XGBoostEstimator(xgboostParam.toMap).setFeaturesCol("features").
  setLabelCol("label")
val paramGrid = new ParamGridBuilder().addGrid(xgbEstimator.round, Array(20, 50)).addGrid(xgbEstimator.eta, Array(0.1, 0.4)).build()
val tv = new TrainValidationSplit().setEstimator(xgbEstimator).setEvaluator(new RegressionEvaluator().setLabelCol("label")).setEstimatorParamMaps(paramGrid).setTrainRatio(0.8)  // Use 3+ in practice


val bestModel = tv.fit(trainDF)
// Out:
// bestModel: org.apache.spark.ml.tuning.TrainValidationSplitModel = tvs_806d5d397a37

// %%
// xgboost-spark appends the column containing prediction results
bestModel.transform(testDF).show()
// Out:
// +-----+--------------------+------------+
// |label|            features|  prediction|
// +-----+--------------------+------------+
// |  0.0|(126,[0,8,18,20,2...| 4.887581E-6|
// |  1.0|(126,[2,8,18,20,2...|  0.99994767|
// |  0.0|(126,[0,8,19,20,2...| 4.887581E-6|
// |  0.0|(126,[2,8,18,20,2...| 4.887581E-6|
// |  0.0|(126,[3,6,10,21,2...|2.4557114E-5|
// |  0.0|(126,[2,9,19,20,2...|2.4852157E-4|
// |  1.0|(126,[2,8,10,20,2...|  0.99994767|
// |  0.0|(126,[0,8,19,20,2...|1.3649464E-5|
// |  1.0|(126,[2,8,18,20,2...|   0.9999572|
// |  0.0|(126,[3,8,19,20,2...|5.0514936E-5|
// |  1.0|(126,[2,8,10,20,2...|  0.99994767|
// |  0.0|(126,[0,8,19,20,2...|1.3649464E-5|
// |  0.0|(126,[3,6,13,21,2...|1.3977289E-5|
// |  0.0|(126,[0,8,18,20,2...| 4.887581E-6|
// |  0.0|(126,[3,9,10,21,2...|1.3977289E-5|
// |  0.0|(126,[3,8,19,20,2...|5.9366226E-5|
// |  0.0|(126,[0,9,19,20,2...|1.3649464E-5|
// |  1.0|(126,[2,8,10,20,2...|  0.99994767|
// |  0.0|(126,[5,6,10,21,2...|2.4557114E-5|
// |  0.0|(126,[2,9,19,20,2...|1.3649464E-5|
// +-----+--------------------+------------+
// only showing top 20 rows

// %% [markdown]
// ### Explain Parameters of the XGBoost Model
// Let's also take a look at the parameters of the model we trained

// %%
bestModel.booster.getModelDump()
// Out:
// res29: Array[String] =
// Array("0:[f28<2] yes=1,no=2,missing=2
// 	1:[f108<2] yes=3,no=4,missing=4
// 		3:leaf=0.185965
// 		4:[f66<2] yes=7,no=8,missing=8
// 			7:[f38<2] yes=13,no=14,missing=14
// 				13:leaf=-0.15
// 				14:leaf=0.177143
// 			8:[f7<2] yes=15,no=16,missing=16
// 				15:leaf=0.1
// 				16:leaf=-0.199117
// 	2:[f55<2] yes=5,no=6,missing=6
// 		5:[f20<2] yes=9,no=10,missing=10
// 			9:leaf=-0.198104
// 			10:leaf=0.177778
// 		6:[f59<2] yes=11,no=12,missing=12
// 			11:leaf=-0.195062
// 			12:[f22<2] yes=17,no=18,missing=18
// 				17:leaf=-0.180952
// 				18:[f23<2] yes=19,no=20,missing=20
// 					19:leaf=-0.18
// 					20:leaf=0.199735
// ", "0:[f28<2] yes=1,no=2,missing=2
// 	1:[f108<2] yes=3,no=4,missing=4
// 		3:leaf=0.170083
// 		4:[f66<2] yes=7,no=8,missing=8
// 			7:[f38<2] yes=13,no=14,missing=14
// 				13:leaf=-0.139357
// 				14:leaf=0.162618...

// %% [markdown]
// ### Save the model to Azure Storage
// XGBoost can save the model to Azure Storage. We need to specify the implicit value sc, which is required by the saveModelAsHadoopFile API. It is the sparkContext type so we need to get it from the default spark (which is of sparkSession type)

// %%
//set sc value which is required by the saveModelAsHadoopFile API. It is the sparkContext type so we need to get it from the default spark (which is of sparkSession type)
implicit val sc = spark.sparkContext
xgboostModel.saveModelAsHadoopFile(outputModelPath)

// %% [markdown]
// ### References
// Most of the code above are copied from XGBoost repository, notebly the [SparkWithDataFrame example](https://github.com/dmlc/xgboost/blob/771a95aec6015aa6de2dcf822220aa064e5fe52c/jvm-packages/xgboost4j-example/src/main/scala/ml/dmlc/xgboost4j/scala/example/spark/SparkWithDataFrame.scala) and [SparkModelTuningTool example](https://github.com/dmlc/xgboost/blob/771a95aec6015aa6de2dcf822220aa064e5fe52c/jvm-packages/xgboost4j-example/src/main/scala/ml/dmlc/xgboost4j/scala/example/spark/SparkModelTuningTool.scala)

// %% [markdown]
// ### Acknowlegement
// Thanks to Nan Zhu (zhna@microsoft.com), Software Engineer in Microsoft for helping out and identifying the potential scala conflict between Livy and XGBoost.
